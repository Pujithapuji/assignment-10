# %%
 
x=[11,22,11,22,11,22,54,54,32,45,32]
y=[]
for i in x:
    if i not in y:
        y.append(i)
print(y)
# Out:
# [11, 22, 54, 32, 45]

# %%
 
k='This is neha kakkar New Album'
l=0
u=0
c=0
for i in k:
    if   i.islower():
        l=l+1
    elif i.isupper():
            u=u+1
    else:
        c=c+1
print("Number of lower case letters",l)
print("Number of upper case letters",u)
# Out:
# Number of lower case letters 21
# Number of upper case letters 3

# %%
 
liste = [109, 67, 44, 23, 64]
new = list(liste)
print(liste)
print(new)
# Out:
# [109, 67, 44, 23, 64]
# [109, 67, 44, 23, 64]

# %%
 
def test(n):
    if n in range(16,20):
        print( " %s is in the range"%str(n))
    else :
        print("The number is outside the given range.")
test(19)
test(21)
test(20)
# Out:
#  19 is in the range
# The number is outside the given range.
# The number is outside the given range.

# %%
 
num = [17,8, 127, 265, 44, 20, 277]
num = [x for x in num if x%2!=0]
print(num)
# Out:
# [17, 127, 265, 277]

# %%
 
color = ['Red', 'Green', 'White', 'Black', 'Pink', 'Yellow']
color = [x for (i,x) in enumerate(color) if i not in (0,4,5)]
print(color)
# Out:
# ['Green', 'White', 'Black']
